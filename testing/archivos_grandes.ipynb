# %%
import sys
import os
import csv
sys.path.append(os.path.abspath("C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/"))
from heuristicas.grid_heuristic import grid_heuristic, solve
from lectura_and_analisis.xml_parsing import xml_data_extractor
from lectura_and_analisis.analisis import calculate_area
from lectura_and_analisis.generacion_mapa import fun_generacion_mapa
from lectura_and_analisis.optimization_functions import change_dimensions, optimize_area

# %%
file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/sqr.02.xml'
polygon, panel_size, restrictions , angulo = xml_data_extractor(file_path_bony)

polygon, panel_size, restrictions, rectangles = change_dimensions(polygon,panel_size,restrictions, size_to_change = 0.01)

# %%
rectangles_sqr2 = grid_heuristic(polygon, panel_size, restrictions,rand = True)
fun_generacion_mapa(polygon,restrictions,rectangles_sqr2,panel_size)
len_rectangles_sqr2 = [len(rect) for rect in rectangles_sqr2]
area_sqr2 = calculate_area(polygon,len_rectangles_sqr2,panel_size)
print(len_rectangles_sqr2)
# Out:
# [18]

# %%
print(area_sqr2)
# Out:
# 0.6666666666666666

# %%
file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/sqr.01.xml'
polygon, panel_size, restrictions , angulo = xml_data_extractor(file_path_bony)

polygon, panel_size, restrictions, rectangles = change_dimensions(polygon,panel_size,restrictions, size_to_change = 0.01)

# %%
rectangles_sqr1 = grid_heuristic(polygon, panel_size, restrictions,rand = False)
fun_generacion_mapa(polygon,restrictions,rectangles_sqr1,panel_size)
len_rectangles_sqr1 = [len(rect) for rect in rectangles_sqr1]
area_sqr1 = calculate_area(polygon,len_rectangles_sqr1,panel_size)
print(area_sqr1)
# Out:
# 0.7407407407407407
