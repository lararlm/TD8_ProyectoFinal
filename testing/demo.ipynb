# %%
import sys
import os
sys.path.append(os.path.abspath("C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/"))
from heuristicas.grid_heuristic import grid_heuristic, solve
from heuristicas.paint_heuristic import paint_heuristic
from analisis.xml_parsing import xml_data_extractor
from analisis.auxiliar_functions import calculate_area, change_dimensions
from analisis.generacion_mapa import plot_solution
from analisis.optimization_functions import  optimize_area

# %%
file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/pol.02.xml' # Elegimos el mapa
polygon, rect_size, restrictions , angulo = xml_data_extractor(file_path_bony)
# Descomentar solamente si el mapa es muy grande
# polygon, rect_size, restrictions, rectangles = change_dimensions(polygon,rect_size,restrictions, size_to_change = 0.01)

# %%
plot_solution(polygon,restrictions,[],rect_size)

# %%
rectangles_demo = grid_heuristic(polygon, restrictions,rect_size,rand = True) # Corremos con el algoritmo de grilla
plot_solution(polygon,restrictions,rectangles_demo,rect_size)
area_demo = calculate_area(polygon,rectangles_demo,rect_size)
print(area_demo)
# Out:
# 0.6643220007815553

# %%
rectangles_demo_2 = paint_heuristic(polygon,restrictions,rect_size) # Corremos con el algoritmo de pintado
plot_solution(polygon,restrictions,rectangles_demo_2,rect_size)
area_demo_2 = calculate_area(polygon,rectangles_demo_2,rect_size)
print(area_demo_2)
# Out:
# 0.6643220007815553

# %%
#Corremos con optimizacion:

opt_rectangles_demo = optimize_area(grid_heuristic,polygon,rectangles_demo,rect_size,restrictions,1,100)
plot_solution(polygon,restrictions,opt_rectangles_demo,rect_size)
area_opt_demo = calculate_area(polygon,rectangles_demo_2,rect_size)
print(area_opt_demo)
# Out:
#   1%|          | 1/100 [00:05<08:30,  5.16s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 #Corremos con optimizacion:
# ----> 3 opt_rectangles_demo = optimize_area(grid_heuristic,polygon,rectangles_demo,rect_size,restrictions,1,100)
#       4 plot_solution(polygon,restrictions,opt_rectangles_demo,rect_size)
#       5 area_opt_demo = calculate_area(polygon,rectangles_demo_2,rect_size)
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\analisis\optimization_functions.py:32, in optimize_area(opt_func, polygon, rectangles, rect_size, restrictions, minimum_rectangles_to_delete, iterations)
#      30     for rect in rectangles_to_remove:
#      31         temporal_rectangles[i].remove(rect)
# ---> 32 temporal_rectangles = opt_func(polygon,restrictions, rect_size, temporal_rectangles, optimizing = True)
#      33 temporal_area = calculate_area(polygon, temporal_rectangles,rect_size)
#      34 if temporal_area > optimal_area:
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:103, in grid_heuristic(polygon, restrictions, rect_size, rand, rectangles, optimizing)
#     101 improvment = False
#     102 actual_rect = rect_size[i]
# --> 103 sub_rectangles = solve(polygon,actual_rect,restrictions,rectangles,rect_size,rand, optimizing)
#     104 if sub_rectangles:
#     105     counter += 1
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:58, in solve(polygon, actual_rect, restrictions, rectangles, rect_size, rand, optimizing)
#      56 Array = generate_panel_arrays(n_x, n_y, actual_rect, real_id, real_offset_x, real_offset_y)
#      57 okay_panels = contains_rectangles(Array, actual_rect, original_polygon)
# ---> 58 okay_panels, okay_centers = check_panels(okay_panels, actual_rect, rect_size, restrictions,rectangles)
#      59 if len(okay_panels) == max_panel:
#      60     change = random.choices([True,False],[6,94])
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:230, in check_panels(panels, actual_rect, rect_size, restrictions, rectangles)
#     228 for i in range(len(panels)):
#     229     center = (panels[i][0] + width/2, panels[i][1] + heigth/2)
# --> 230     if check_center(center,restrictions) and check_rectangles(center,actual_rect,rect_size,rectangles):
#     231         true_panels.append(panels[i])
#     232         true_centers.append(center)
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:136, in check_center(center, restrictions)
#     134 for rest in restrictions:
#     135     center_point = Point(center)
# --> 136     fig_rest = Polygon(rest)
#     137     is_in_rest = center_point.within(fig_rest)
#     138     if is_in_rest:
#
# File c:\Users\valen\miniconda3\envs\IA\Lib\site-packages\shapely\geometry\polygon.py:239, in Polygon.__new__(self, shell, holes)
#     236     else:
#     237         holes = [LinearRing(ring) for ring in holes]
# --> 239 geom = shapely.polygons(shell, holes=holes)
#     240 if not isinstance(geom, Polygon):
#     241     raise ValueError("Invalid values passed to Polygon constructor")
#
# File c:\Users\valen\miniconda3\envs\IA\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\valen\miniconda3\envs\IA\Lib\site-packages\shapely\creation.py:265, in polygons(geometries, holes, indices, out, **kwargs)
#     262     if np.issubdtype(holes.dtype, np.number):
#     263         holes = linearrings(holes)
# --> 265 return lib.polygons(geometries, holes, out=out, **kwargs)
#
# KeyboardInterrupt:

# %%
opt_rectangles_demo_2 = optimize_area(grid_heuristic,polygon,rectangles_demo_2,rect_size,restrictions,1,100)
plot_solution(polygon,restrictions,opt_rectangles_demo_2,rect_size)
area_opt_demo_2 = calculate_area(polygon,rectangles_demo_2,rect_size)
print(area_opt_demo_2)
