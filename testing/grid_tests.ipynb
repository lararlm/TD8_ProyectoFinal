# %%
import sys
import os
sys.path.append(os.path.abspath("C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/"))
from heuristicas.grid_heuristic import grid_heuristic, solve
from lectura_and_analisis.xml_parsing import xml_data_extractor
from lectura_and_analisis.analisis import calculate_area
from lectura_and_analisis.generacion_mapa import fun_generacion_mapa
from lectura_and_analisis.optimization_functions import change_dimensions, optimize_area
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import os
#       3 sys.path.append(os.path.abspath("C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/"))
# ----> 4 from heuristicas.grid_heuristic import grid_heuristic, solve
#       5 from lectura_and_analisis.xml_parsing import xml_data_extractor
#       6 from lectura_and_analisis.analisis import calculate_area
#
# ModuleNotFoundError: No module named 'heuristicas'

# %%
file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/pol.02.xml'
polygon, panel_size, restrictions , angulo = xml_data_extractor(file_path_bony)

# %%
fun_generacion_mapa(polygon,restrictions,[],panel_size)

# %%
rectangles_02 = grid_heuristic(polygon, panel_size, restrictions,rand = True)
fun_generacion_mapa(polygon,restrictions,rectangles_02,panel_size)
len_rectangles_02 = [len(rect) for rect in rectangles_02]
area_02 = calculate_area(polygon,len_rectangles_02,panel_size)
print(len_rectangles_02)
# Out:
# [18]

# %%
print(area_02)
# Out:
# 0.7033997655334114

# %%
# Corrected path to save the CSV
csv_path = r'C:\Users\valen\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\solutions\pol.02\best_rectangles0.csv'

# Find the maximum length of the lists inside best_rectangles
max_length = max(len(lst) for lst in rectangles_02)

# Save best_rectangles to a CSV file
with open(csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write header: Separate 'x' and 'y' for each pair of coordinates
    header = []
    for i in range(len(rectangles_02)):
        header.append(f'x{i}')
        header.append(f'y{i}')
    writer.writerow(header)
    
    # Iterate through each "row" index up to the maximum length
    for i in range(max_length):
        row = []
        for rect_list in rectangles_02:
            if i < len(rect_list):
                row.extend([rect_list[i][0], rect_list[i][1]])  # Add x and y coordinates as floats/ints
            else:
                row.extend([None, None])  # Use None for missing values to avoid quotes
        writer.writerow(row)

# %%
print(area)
best_rectangles = optimize_area(grid_heuristic,polygon,rectangles,panel_size,restrictions,3,100)
# Out:
# 0.6252442360296991
#   0%|          | 0/100 [00:00<?, ?it/s]
#  92%|█████████▏| 92/100 [37:35<03:16, 24.52s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 print(area)
# ----> 2 best_rectangles = optimize_area(grid_heuristic,polygon,rectangles,panel_size,restrictions,3,100)
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\lectura_and_analisis\optimization_functions.py:18, in optimize_area(opt_func, polygon, rectangles, panel_size, restrictions, minimum_rectangles_to_delete, iterations)
#      16     for rect in rectangles_to_remove:
#      17         temporal_rectangles[i].remove(rect)
# ---> 18 temporal_rectangles = opt_func(polygon,panel_size,restrictions,temporal_rectangles)
#      19 len_temp_rectangles =  [len(rect) for rect in temporal_rectangles]
#      20 temporal_area = calculate_area(polygon,len_temp_rectangles,panel_size)
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:132, in grid_heuristic(polygon, panel_size, restrictions, rectangles)
#     128             true_centers.append(center)
#     129     return true_panels, true_centers
# --> 132 def grid_heuristic(polygon, panel_size, restrictions, rand = False, rectangles = None):
#     133     if not rectangles:
#     134         rectangles = [[] for _ in range(len(panel_size))]
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:44, in solve(polygon, actual_panel, restrictions, rectangles, panel_size)
#      42 epsilon_y = 0
#      43 epsilon_id = 0
# ---> 44 if rand:
#      45     random_movements = np.random.normal(0,0.2,3)
#      46 real_offset_x = offset_x + random_movements[0]
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:118, in check_panels(panels, actual_panel, panel_size, restrictions, rectangles)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:104, in check_center(center, restrictions)
#     102 bbpath = matplotlib.path.Path(polygon)
#     103 result = bbpath.contains_points([(x, y), (x + dx, y), (x, y + dy), (x + dx, y + dy)])
# --> 104 return np.all(result)
#
# File c:\Users\valen\miniconda3\envs\IA\Lib\site-packages\shapely\geometry\point.py:78, in Point.__new__(self, *args)
#      76 if not np.issubdtype(coords.dtype, np.number):
#      77     coords = [float(c) for c in coords]
# ---> 78 geom = shapely.points(coords)
#      79 if not isinstance(geom, Point):
#      80     raise ValueError("Invalid values passed to Point constructor")
#
# File c:\Users\valen\miniconda3\envs\IA\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\valen\miniconda3\envs\IA\Lib\site-packages\shapely\creation.py:74, in points(coords, y, z, indices, out, **kwargs)
#      72 coords = _xyz_to_coords(coords, y, z)
#      73 if indices is None:
# ---> 74     return lib.points(coords, out=out, **kwargs)
#      75 else:
#      76     return simple_geometries_1d(coords, indices, GeometryType.POINT, out=out)
#
# KeyboardInterrupt:

# %%
# Corrected path to save the CSV
csv_path = r'C:\Users\valen\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\solutions\pol.1s.07\best_rectangles1.csv'

# Find the maximum length of the lists inside best_rectangles
max_length = max(len(lst) for lst in best_rectangles_2)

# Save best_rectangles to a CSV file
with open(csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write header: Separate 'x' and 'y' for each pair of coordinates
    header = []
    for i in range(len(best_rectangles_2)):
        header.append(f'x{i}')
        header.append(f'y{i}')
    writer.writerow(header)
    
    # Iterate through each "row" index up to the maximum length
    for i in range(max_length):
        row = []
        for rect_list in best_rectangles_2:
            if i < len(rect_list):
                row.extend([rect_list[i][0], rect_list[i][1]])  # Add x and y coordinates as floats/ints
            else:
                row.extend([None, None])  # Use None for missing values to avoid quotes
        writer.writerow(row)

# %%
file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/pol.1s.00.xml'
polygon, panel_size, restrictions , angulo = xml_data_extractor(file_path_bony)
best_rectangles_1s = grid_heuristic(polygon, panel_size, restrictions,rand = True)
fun_generacion_mapa(polygon,restrictions,best_rectangles_1s,panel_size)
len_rectangles_1s = [len(rect) for rect in best_rectangles_1s]
area_1s = calculate_area(polygon,len_rectangles_1s,panel_size)
print(len_rectangles_1s)
print(area_1s)
# Out:
# [11]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       6 area = calculate_area(polygon,len_rectangles,panel_size)
#       7 print(len_rectangles_1s)
# ----> 8 print(area_1s)
#
# NameError: name 'area_1s' is not defined

# %%
area_1s = calculate_area(polygon,len_rectangles_1s,panel_size)
print(len_rectangles_1s)
print(area_1s)
# Out:
# [11]
# 0.7857142857142857

# %%
import csv
# Corrected path to save the CSV
csv_path = r'C:\Users\valen\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\solutions\pol.1s.00\best_rectangles0.csv'

# Find the maximum length of the lists inside best_rectangles
max_length = max(len(lst) for lst in best_rectangles_1s)

# Save best_rectangles to a CSV file
with open(csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write header: Separate 'x' and 'y' for each pair of coordinates
    header = []
    for i in range(len(best_rectangles_1s)):
        header.append(f'x{i}')
        header.append(f'y{i}')
    writer.writerow(header)
    
    # Iterate through each "row" index up to the maximum length
    for i in range(max_length):
        row = []
        for rect_list in best_rectangles_1s:
            if i < len(rect_list):
                row.extend([rect_list[i][0], rect_list[i][1]])  # Add x and y coordinates as floats/ints
            else:
                row.extend([None, None])  # Use None for missing values to avoid quotes
        writer.writerow(row)

# %%
file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/pol.1s.01.xml'
polygon, panel_size, restrictions , angulo = xml_data_extractor(file_path_bony)
rectangles = grid_heuristic(polygon, panel_size, restrictions,rand = True)
fun_generacion_mapa(polygon,restrictions,rectangles,panel_size)
len_rectangles = [len(rect) for rect in rectangles]
area = calculate_area(polygon,len_rectangles,panel_size)
print(len_rectangles)
print(area)
# Out:
# [8]
# 0.6565064478311841

# %%
file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/pol.1s.02.xml'
polygon, panel_size, restrictions , angulo = xml_data_extractor(file_path_bony)
rectangles = grid_heuristic(polygon, panel_size, restrictions,rand = True)
fun_generacion_mapa(polygon,restrictions,rectangles,panel_size)
len_rectangles = [len(rect) for rect in rectangles]
area = calculate_area(polygon,len_rectangles,panel_size)
print(len_rectangles)
print(area)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/pol.1s.02.xml'
#       2 polygon, panel_size, restrictions , angulo = xml_data_extractor(file_path_bony)
# ----> 3 rectangles = grid_heuristic(polygon, panel_size, restrictions,rand = True)
#       4 fun_generacion_mapa(polygon,restrictions,rectangles,panel_size)
#       5 len_rectangles = [len(rect) for rect in rectangles]
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:140, in grid_heuristic(polygon, panel_size, restrictions, rand, rectangles)
#     138 improvment = False
#     139 actual_panel = panel_size[i]
# --> 140 sub_rectangles = solve(polygon,actual_panel,restrictions,rectangles,panel_size,rand)
#     141 if sub_rectangles:
#     142     improvment = True
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:51, in solve(polygon, actual_panel, restrictions, rectangles, panel_size, rand)
#      49 change = False
#      50 Array = generate_panel_arrays(n_x, n_y, actual_panel, real_id, real_offset_x, real_offset_y)
# ---> 51 okay_panels = contains_rectangles(Array, actual_panel, original_polygon)
#      52 okay_panels, okay_centers = check_panels(okay_panels, actual_panel, panel_size, restrictions,rectangles)
#      54 if len(okay_panels) == max_panel:
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:107, in contains_rectangles(Array, panel_size, polygon)
#     106 def contains_rectangles(Array, panel_size, polygon):
# --> 107     okay_panels  = [(x, y) for (x, y) in Array if contains_rectangle(x, y, panel_size, polygon)]
#     108     return okay_panels
#
# File ~\OneDrive\Escritorio\Bony\Di tella\TD8FINAL\TD8_ProyectoFinal\heuristicas\grid_heuristic.py:103, in contains_rectangle(x, y, panel_size, polygon)
#     101 (dx, dy) = panel_size
#     102 bbpath = matplotlib.path.Path(polygon)
# --> 103 result = bbpath.contains_points([(x, y), (x + dx, y), (x, y + dy), (x + dx, y + dy)])
#     104 return np.all(result)
#
# File c:\Users\valen\miniconda3\envs\IA\Lib\site-packages\matplotlib\path.py:594, in Path.contains_points(self, points, transform, radius)
#     592     transform = transform.frozen()
#     593 result = _path.points_in_path(points, radius, self, transform)
# --> 594 return result.astype('bool')
#
# KeyboardInterrupt:

# %%
file_path_bony = 'C:/Users/valen/OneDrive/Escritorio/Bony/Di tella/TD8FINAL/TD8_ProyectoFinal/mapas/test.01.xml'
polygon, panel_size, restrictions , angulo = xml_data_extractor(file_path_bony)
rectangles_test_1 = grid_heuristic(polygon, panel_size, restrictions,rand = True)
fun_generacion_mapa(polygon,restrictions,rectangles_test_1,panel_size)
len_rectangles_test_1 = [len(rect) for rect in rectangles_test_1]
area_test_1 = calculate_area(polygon,len_rectangles_test_1,panel_size)
print(len_rectangles_test_1)
print(area_test_1)
# Out:
# [18]
# 0.675
